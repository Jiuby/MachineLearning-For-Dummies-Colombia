# %%
# Predicción del Tiempo de Estudio para una Prueba

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Cargar los datos

# TIEMPO DE ESTUDIO (X) y CALIFICACIÓN (Y)
X = np.array([[30], [50], [70], [90], [130], [160], [190], [210], [230], [250]])  
y = np.array([1.0, 2.0, 2.5, 3.0, 3.5, 4.0, 4.3, 4.5, 4.7, 5.0])  # Array unidimensional para las etiquetas

# %%
# Graficamos los datos
plt.scatter(x, y)
plt.xlabel('Tiempo de Estudio (Horas)')
plt.ylabel('Calificación')
plt.grid(True)
plt.show()

# %%
# Creamos el modelo de regresión lineal
modelo = LinearRegression()

# Entrenamos el modelo con nuestros datos
modelo.fit(X, y)

# Hacemos una predicción
tiempo_prediccion = modelo.predict([[120]])
print("Predicción para tiempo de estudio de 120:", tiempo_prediccion)
# Out:
# Predicción para tiempo de estudio de 120: [3.11118693]

# %%
plt.scatter(X, y, color='blue', label='Datos reales')
plt.plot(X, modelo.predict(X), color='red', linewidth=2, label='Línea de regresión')
plt.xlabel('Tiempo de Estudio (X)')
plt.ylabel('Calificación (Y)')
plt.title('Regresión Lineal: Tiempo de Estudio vs. Calificación')
plt.legend()
plt.show()
