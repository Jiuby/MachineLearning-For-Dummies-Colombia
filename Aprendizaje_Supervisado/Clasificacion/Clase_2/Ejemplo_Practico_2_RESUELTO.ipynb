# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#verificar si hay valores nulos
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# vamos a seleccionar los valores que vamos a utilizar

x = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = df[['Outcome']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# creamo el modelo

model = DecisionTreeClassifier()

model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# hacemos la prediccion

y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)

print(f'Precisión del modelo: {accuracy * 100:.2f}%')
# Out:
# Precisión del modelo: 74.68%

# %%
# 0: No tiene diabetes
# 1: Tiene diabetes

# vamos a hacer una predicción

# 1. Una mujer de 30 años, con 5 embarazos, con un nivel de glucosa de 120, presión arterial de 80, grosor de piel de 20, insulina de 50, IMC de 30 y función de pedigrí de diabetes de 0.5

print("Ejemplo 1", model.predict([[5, 120, 80, 20, 50, 30, 0.5, 30]]))

# 2. Una mujer de 50 años, con 2 embarazos, con un nivel de glucosa de 200, presión arterial de 90, grosor de piel de 30, insulina de 100, IMC de 35 y función de pedigrí de diabetes de 0.8

print("Ejemplo 2", model.predict([[2, 200, 90, 30, 100, 35, 0.8, 50]]))
# 3. Una mujer de 40 años, con 3 embarazos, con un nivel de glucosa de 150, presión arterial de 70, grosor de piel de 25, insulina de 80, IMC de 25 y función de pedigrí de diabetes de 0.6

print("Ejemplo 3", model.predict([[3, 150, 70, 25, 80, 25, 0.6, 40]]))
# 4. Una mujer de 60 años, con 1 embarazo, con un nivel de glucosa de 100, presión arterial de 60, grosor de piel de 10, insulina de 20, IMC de 20 y función de pedigrí de diabetes de 0.3

print("Ejemplo 4", model.predict([[1, 100, 60, 10, 20, 20, 0.3, 60]]))
# 5. Una mujer de 20 años, con 4 embarazos, con un nivel de glucosa de 180, presión arterial de 100, grosor de piel de 40, insulina de 150, IMC de 40 y función de pedigrí de diabetes de 0.9
print("Ejemplo 5", model.predict([[4, 180, 100, 40, 150, 40, 0.9, 20]]))
# Out:
# Ejemplo 1 [0]
# Ejemplo 2 [1]
# Ejemplo 3 [0]
# Ejemplo 4 [0]
# Ejemplo 5 [1]
# C:\Users\hitak\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\hitak\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\hitak\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\hitak\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ...
